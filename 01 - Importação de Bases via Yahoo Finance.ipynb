# %%
"""
Script para dar permissão de administrador no Windows 10
Permitindo a instação de pacotes dentro do próprio script Python
Uso recomendado: Notebooks Pessoais
"""
import os
import sys
import win32com.shell.shell as shell
ASADMIN = 'asadmin'


if sys.argv[-1] != ASADMIN:
    script = os.path.abspath(sys.argv[0])
    params = ' '.join([script] + sys.argv[1:] + [ASADMIN])
    shell.ShellExecuteEx(lpVerb='runas', lpFile=sys.executable, lpParameters=params)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import yfinance as yf

# %%
"""Sobrescrevendo os métodos do pandas_datareader"""
yf.pdr_override()

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov
# Out:
#                      Open           High            Low          Close  \
# Date
# 1993-04-27      24.799999      25.400000      24.500000      24.500000
# 1993-04-28      24.500000      24.600000      23.700001      24.299999
# 1993-04-29      24.299999      24.799999      23.700001      23.700001
# 1993-04-30      23.700001      24.200001      23.700001      24.100000
# 1993-05-03      24.100000      24.400000      23.799999      24.100000
# ...                   ...            ...            ...            ...
# 2022-04-12  116963.000000  118615.000000  116054.000000  116147.000000
# 2022-04-13  116150.000000  117329.000000  116150.000000  116782.000000
# 2022-04-14  116781.000000  116781.000000  115624.000000  116182.000000
# 2022-04-18  116182.000000  116191.000000  115177.000000  115687.000000
# 2022-04-19  115686.953125  115686.953125  114277.156250  114964.171875
#
#                 Adj Close    Volume
# Date
# 1993-04-27      24.500000         0
# ...

# %%
ibov["Close"].plot(figsize=(22,8));

# %%
sp500 = web.get_data_yahoo('^GSPC')
sp500["Close"].plot(figsize=(22,8));
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gold = web.get_data_yahoo('GC=F')
gold["Close"].plot(figsize=(22,8));
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dolar = web.get_data_yahoo('USDBRL=X')
dolar["Close"].plot(figsize=(22,8));
# Out:
# [*********************100%***********************]  1 of 1 completed
